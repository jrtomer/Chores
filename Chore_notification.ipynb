# %%
# Download the helper library from https://www.twilio.com/docs/python/install
import os
from twilio.rest import Client
import pandas as pd
# Set environment variables for your credentials
# Read more at http://twil.io/secure

"Practice_Schedule.csv"
def schedule(filename):
    
    #This variable will stay constant
    directory = "/Users/jrtomer/Documents"
    
    filename_path = os.path.abspath(os.path.join(directory, filename))
    schedule_data = pd.read_csv(filename_path)
    return(schedule_data)


    
    
def notify_person(number, name):
    account_sid = "AC0e8075efe8564b60f66b4e4547586941"
    auth_token = "cf6e3ac95c560ddf7a9b46c99208d276"
    client = Client(account_sid, auth_token)

    message = client.messages.create(
      body="Chore time %s" %name,
      from_="+18337710898",
      to="%s" %number
    )

    print("Sent message")

# %%
import pandas as pd
import numpy as np
# Set environment variables for your credentials
# Read more at http://twil.io/secure

"Practice_Schedule.csv"
def schedule(filename):
    
    #This variable will stay constant
    directory = "/Users/jrtomer/Documents"
    
    filename_path = os.path.abspath(os.path.join(directory, filename))
    schedule_data = pd.read_csv(filename_path)
    return(schedule_data)

schedule_data = schedule("Practice_Schedule.csv")

def sorting_schedule(schedule_data):
    
    #0 is bathroom
    #1 is kitchen
    #2 is living room
    #3 is hallway
    
    for j in range(4):
        
        x = schedule_data.iloc[j,0]
    
        if x == 'Kitchen':
            i = j
            kitchen_list = []
            kitchen_list.append((schedule_data.loc[i]))
       
        if x == 'Bathroom':
            i = j
            bathroom_list = []
            bathroom_list.append((schedule_data.loc[i]))
            
        if x == 'Hallway':
            i = j
            hallway_list = []
            hallway_list.append((schedule_data.loc[i]))
            
        if x == 'Living Room':
            i = j
            livingroom_list = []
            livingroom_list.append((schedule_data.loc[i]))
            
            
    big_list = [bathroom_list, livingroom_list, kitchen_list, hallway_list]
    return(big_list, bathroom_list, livingroom_list, kitchen_list, hallway_list)

big_list, bathroom_list, livingroom_list, kitchen_list, hallway_list = sorting_schedule(schedule_data)
print(schedule_list)
# Out:
# [[Unnamed: 0    Bathroom
# 7-Feb             Gabe
# 14-Feb             NaN
# 21-Feb           Jacob
# 28-Feb             NaN
# Name: 0, dtype: object], [Unnamed: 0    Living Room
# 7-Feb                Matt
# 14-Feb              Megan
# 21-Feb               Gabe
# 28-Feb               Leif
# Name: 2, dtype: object], [Unnamed: 0    Kitchen
# 7-Feb           Jacob
# 14-Feb           Leif
# 21-Feb           Matt
# 28-Feb        Alessio
# Name: 1, dtype: object], [Unnamed: 0    Hallway
# 7-Feb         Dichali
# 14-Feb        Alessio
# 21-Feb        Dichali
# 28-Feb          Megan
# Name: 3, dtype: object]]

# %%
def schedule(filename):
    
    #This variable will stay constant
    directory = "/Users/jrtomer/Documents"
    
    filename_path = os.path.abspath(os.path.join(directory, filename))
    schedule_data = pd.read_csv(filename_path)
    return(schedule_data)

schedule_data = schedule("Practice_Schedule.csv")
schedule_data.iloc[2,1]

for j in range(4):
        
    x = schedule_data.iloc[j,0]
    
    if x == 'Kitchen':
        i = j
        kitchen_list = []
        kitchen_list.append((schedule_data.loc[i]))



big_list

# This function sorts through a single weeks worth of chores
# Then, it assigns the name of the person to that chore

def assigning_chores(big_list, week):
    
    
    for x in range(len(big_list)):

        chore_list = big_list[x][0][0]
        
        if chore_list == "Kitchen":
                kitchen = kitchen_list[0][week]
                
        if chore_list == "Bathroom":
                bathroom = bathroom_list[0][week]
                
        if chore_list == "Hallway":
                hallway = hallway_list[0][week]
                
        if chore_list == "Living Room":
                livingroom = livingroom_list[0][week]
    return(kitchen, bathroom, hallway, livingroom)

kitchen, bathroom, hallway, livingroom = assigning_chores(big_list, 1)
chores = [kitchen, bathroom, hallway, livingroom]

# A dictionary that keys names to their phone numbers
# The downside of this is that the excel chore sheet has to be formatted
# in a very specific way
phone_dict = {}

phone_dict['Matt'] = "+12537542040"
phone_dict['Dichali'] = "+12063277797"
phone_dict['Jacob'] = "+14126604836"
phone_dict['Leif'] = "+12068835613"
phone_dict['Alessio'] = "+12067470127"
phone_dict['Megan'] = "+12067431487"
phone_dict['Gabe'] = "+12064654438"

def notifying(chores):
    chore_list = ["KITCHEN", "BATHROOM", "HALLWAY", "LIVINGROOM"]
    i = 0
    for person in chores:
        account_sid = "AC0e8075efe8564b60f66b4e4547586941"
        auth_token = "cf6e3ac95c560ddf7a9b46c99208d276"
        client = Client(account_sid, auth_token)
        message = client.messages.create(
          body = ("Time to clean the %s %s" %(chore_list[i],person)),
          from_="+18337710898",
          to = phone_dict[person]
        )
        i =+ 1
        
notifying(chores)
# Out:
# Bathroom
# Living Room
# Kitchen
# Hallway
# ---------------------------------------------------------------------------
# TwilioRestException                       Traceback (most recent call last)
# <ipython-input-141-e4bcf208319b> in <module>
#      72         i =+ 1
#      73
# ---> 74 notifying(chores)
#
# <ipython-input-141-e4bcf208319b> in notifying(chores)
#      65         auth_token = "cf6e3ac95c560ddf7a9b46c99208d276"
#      66         client = Client(account_sid, auth_token)
# ---> 67         message = client.messages.create(
#      68           body = ("Time to clean the %s %s" %(chore_list[i],person)),
#      69           from_="+18337710898",
#
# ...

# %%
import os
from twilio.rest import Client
import pandas as pd

#Phone dictionary

phone_dict = {}

phone_dict['Matt'] = "+12537542040"
phone_dict['Dichali'] = "+12063277797"
phone_dict['Jacob'] = "+14126604836"
phone_dict['Leif'] = "+12068835613"
phone_dict['Alessio'] = "+12067470127"
phone_dict['Megan'] = "+12067431487"
phone_dict['Gabe'] = "+12064654438"

def schedule(filename):
    
    #This variable will stay constant
    directory = "/Users/jrtomer/Documents"
    
    filename_path = os.path.abspath(os.path.join(directory, filename))
    schedule_data = pd.read_csv(filename_path)
    return(schedule_data)

schedule_data = schedule("Practice_Schedule.csv")


def sorting_schedule(schedule_data):
    
    #0 is bathroom
    #1 is kitchen
    #2 is living room
    #3 is hallway
    
    for j in range(4):
        
        x = schedule_data.iloc[j,0]
    
        if x == 'Kitchen':
            i = j
            kitchen_list = []
            kitchen_list.append((schedule_data.loc[i]))
       
        if x == 'Bathroom':
            i = j
            bathroom_list = []
            bathroom_list.append((schedule_data.loc[i]))
            
        if x == 'Hallway':
            i = j
            hallway_list = []
            hallway_list.append((schedule_data.loc[i]))
            
        if x == 'Living Room':
            i = j
            livingroom_list = []
            livingroom_list.append((schedule_data.loc[i]))
            
            
    big_list = [bathroom_list, livingroom_list, kitchen_list, hallway_list]
    return(big_list, bathroom_list, livingroom_list, kitchen_list, hallway_list)

big_list, bathroom_list, livingroom_list, kitchen_list, hallway_list = sorting_schedule(schedule_data)       


def assigning_chores(big_list, week):
    
    
    for x in range(len(big_list)):

        chore_list = big_list[x][0][0]
        
        if chore_list == "Kitchen":
                kitchen = kitchen_list[0][week]
                
        if chore_list == "Bathroom":
                bathroom = bathroom_list[0][week]
                
        if chore_list == "Hallway":
                hallway = hallway_list[0][week]
                
        if chore_list == "Living Room":
                livingroom = livingroom_list[0][week]
    chores = [kitchen, bathroom, hallway, livingroom]
    return(chores)

chores = assigning_chores(big_list, 1)


def notifying(chores):
    chore_list = ["KITCHEN", "BATHROOM", "HALLWAY", "LIVINGROOM"]
    i = 0
    for person in chores:
        account_sid = "AC0e8075efe8564b60f66b4e4547586941"
        auth_token = "cf6e3ac95c560ddf7a9b46c99208d276"
        client = Client(account_sid, auth_token)
        message = client.messages.create(
          body = ("Time to clean the %s %s" %(chore_list[i],person)),
          from_="+18337710898",
          to = phone_dict[person]
        )
        i =+ 1

# %%
#Twilio failsafe verification: 0lAVGBIFKaSKwX1SxMKGsuhZfF2DWuouNGohfRxY
def automate(week):
    
    phone_dict = {}

    phone_dict['Matt'] = "+12537542040"
    phone_dict['Dichali'] = "+12063277797"
    phone_dict['Jacob'] = "+14126604836"
    phone_dict['Leif'] = "+12068835613"
    phone_dict['Alessio'] = "+12067470127"
    phone_dict['Megan'] = "+12067431487"
    phone_dict['Gabe'] = "+12064654438"

    schedule_data = schedule("Practice_Schedule.csv")
    big_list, bathroom_list, livingroom_list, kitchen_list, hallway_list = sorting_schedule(schedule_data)  
    chores = assigning_chores(big_list, week)
    notifying(chores)
    
    print("Notifications Sent!")
